# %% [markdown]
# ## Starting with parametric method in pandas and scipy

# %% [markdown]
# ### Pearson Correlation Analysis — Complete Explanation & Study Notes
#
# Correlation: A statistical measure that shows the strength and direction of the relationship between two variables. It ranges from -1 to +1.
#
# Pearson Correlation: A method used to measure the linear relationship between two continuous numeric variables. Its coefficient r ranges from -1 (perfect negative) to +1 (perfect positive), while 0 means no linear correlation.
#
# #### 1. What is Parametric Correlation Analysis?
#
# Parametric correlation analysis is a statistical method used to measure the relationship between **two continuous numeric variables** that are **linearly related**.
#
# Example:
#
# * Height and weight
# * Study hours and marks
# * Car weight and fuel efficiency
#
#
# #### Simple meaning
#
# * **Continuous numeric variable** → can take many numeric values (65.2, 65.3, 65.4…).
# * **Linear relationship** → when one variable increases, the other tends to increase or decrease in a roughly straight-line pattern.
#
# ---
#
# #### 2. The Most Important Warning: Correlation ≠ Causation
#
# An obesity example:
#
# * Grocery store size by zip code.
# * Obesity rate by zip code.
#
# Suppose Pearson correlation shows a strong positive relationship: larger grocery stores are found in areas with higher obesity rates. That **does not mean** large stores cause obesity. They are only associated.
#
# Possible hidden factors:
#
# * Urbanization
# * Income
# * Lifestyle
# * Transportation
# * Population density
#
# #### Exam sentence
#
# **Correlation measures association, not cause-and-effect.**
#
# ---
#
# #### 3. Pearson Correlation Coefficient (r)
#
# Pearson correlation is measured by **r**, which ranges from **−1 to +1**.
#
# | r value | Meaning                              |
# | ------- | ------------------------------------ |
# | +1      | Perfect positive linear relationship |
# | +0.8    | Strong positive relationship         |
# | 0       | No linear relationship               |
# | −0.8    | Strong negative relationship         |
# | −1      | Perfect negative linear relationship |
#
# Interpretation from the lecture:
#
# * **Close to +1** → strong positive relationship.
# * **Close to −1** → strong negative relationship.
# * **Close to 0** → little or no linear relationship.
#
# ---
#
# #### 4. Positive vs Negative Correlation
#
# - Positive
#
# As X increases, Y increases.
#
# Example:
#
# * Store size ↑ → obesity ↑
#
# - Negative
#
# As X increases, Y decreases.
#
# Example:
#
# * Car weight ↑ → fuel efficiency (mpg) ↓
#
# ---
#
# #### 5. Assumptions of Pearson Correlation
#
# The three assumptions.
#
# A. Data should be approximately normally distributed
#
# The histogram should look roughly like a **bell curve**.
#
# Not every variable must be perfectly normal; approximately normal is often acceptable.
#
# B. Variables should be linearly related
#
# Scatter plot points should form an upward or downward trend that resembles a straight line.
#
# C. Variables must be continuous numeric variables
#
# Good examples:
#
# * mpg
# * hp
# * qsec
# * wt
#
# Bad examples:
#
# * gear (3, 4, 5 only)
# * am (0 or 1)
#
# These are categorical/discrete variables and do not satisfy the continuous-variable assumption.
#
# ---
#
# #### 6. Important Limitation
#
# > Pearson correlation can detect **linear relationships**, but it **cannot rule out non-linear relationships**.
#
# So if r ≈ 0, the variables may still have a curved relationship.
#
# Example:
#
# * X = −2, −1, 0, 1, 2
# * Y = 4, 1, 0, 1, 4
#
# This is a U-shaped relationship; Pearson may report a value near zero.
#
# ---
#
# #### What pairplot shows
#
# * **Diagonal** → histogram/distribution of each variable.
# * **Off-diagonal** → scatter plot for every pair of variables.
#
# ### What to look for
#
# * Bell-shaped histograms → approximate normality.
# * Upward/downward scatter pattern → possible linear relationship.
# * Random cloud → weak or no linear relationship.
#
# ---
#
# #### 7. Why Correlation Matters in Machine Learning
#
# Many ML and statistical models make assumptions about relationships among features.
#
# Correlation analysis helps you:
#
# * detect related features,
# * check feature independence,
# * identify multicollinearity,
# * choose variables for advanced models.
#
# Example:
#
# If two features are extremely correlated, using both may add redundant information.
#
# ---
#
# ##### 8. Shortcut Using Pandas
#
# Instead of calculating pairs one by one:
#
# ```python
# corr = x.corr()
# print(corr)
# ```
#
# This produces the full correlation matrix.
#
# Example structure:
#
# |      | mpg   | hp    | qsec  | wt    |
# | ---- | ----- | ----- | ----- | ----- |
# | mpg  | 1.00  | -0.78 | 0.42  | -0.87 |
# | hp   | -0.78 | 1.00  | -0.71 | 0.66  |
# | qsec | 0.42  | -0.71 | 1.00  | -0.17 |
# | wt   | -0.87 | 0.66  | -0.17 | 1.00  |
#
# #### Read it
#
# * mpg & wt = −0.87 → strong negative.
# * hp & wt = 0.66 → positive.
# * qsec & wt = −0.17 → weak.
#
# ---
#
# #### 9. Heatmap Visualization
#
# ```python
# sns.heatmap(corr,
#             xticklabels=corr.columns.values,
#             yticklabels=corr.columns.values)
# ```
#
# explains the colors:
#
# * Dark red → strong positive correlation.
# * Dark opposite shade → strong negative correlation.
# * Mid/faint color → weak relationship.
#
# #### Observations mentioned
#
# * **hp and wt** → strongest positive relationship.
# * **mpg and wt** → strongest negative relationship.
# * **qsec and wt** → weak linear relationship.
#
# Also, every variable has correlation **1.0 with itself**, so the diagonal is always perfect correlation. <FileCite ref_id="turn0file0"/>
#
# ---
#
# #### 10. Very Important Final Point
#
# > A weak Pearson correlation does **not** prove that no relationship exists; it only indicates weak **linear** correlation. Non-linear methods may still detect a relationship.
#
# ---
#
# #### 11. Quick Comparison Table
#
# | Concept              | Meaning                                            |
# | -------------------- | -------------------------------------------------- |
# | Correlation          | Association between variables                      |
# | Causation            | One variable produces change in another            |
# | Pearson r            | Measures linear correlation                        |
# | Positive correlation | Both move in same direction                        |
# | Negative correlation | Move in opposite directions                        |
# | r near 0             | Little/no linear relationship                      |
# | Pairplot             | Visualize distributions and pairwise relationships |
# | Heatmap              | Color-coded correlation matrix                     |
# | Continuous variable  | Numeric with many possible values                  |
# | Categorical variable | Limited set of labels/values                       |
#
# ---
#
# #### 12. Interview-Style Questions
#
# #### Q1. What is Pearson correlation?
#
# A measure of the strength and direction of a **linear relationship** between two continuous numeric variables.
#
# #### Q2. What are its assumptions?
#
# * Approximate normality
# * Linear relationship
# * Continuous numeric variables
#
# #### Q3. Does correlation imply causation?
#
# No.
#
# #### Q4. What does r = −0.87 mean?
#
# Strong negative linear relationship.
#
# #### Q5. Why use a pairplot before Pearson correlation?
#
# To visually check normality, linearity, and outliers.
#
#
# #### 13. One-Page Revision Notes
#
# ###### Pearson Correlation Cheat Sheet
#
# ##### Formula idea
#
# Measures how two variables move together.
#
# ##### Range
#
# * −1 → perfect negative
# * 0 → no linear relation
# * +1 → perfect positive
#
# ##### Assumptions
#
# * Normal distribution
# * Linear relation
# * Continuous numeric data
#
# ##### Do not use for
#
# * Categories like gear, am
# * Strongly curved relationships
#
# #### Interpretation
#
# * |r| > 0.7 → strong
# * 0.3–0.7 → moderate
# * < 0.3 → weak
#
# #### Remember
#
# **Correlation ≠ Causation**
#
# A strong r means variables move together, not that one causes the other.
#
# ---
#
# # 20. The 30-Second Exam Answer
#
# Pearson correlation is a parametric statistical technique that measures the strength and direction of a **linear relationship** between two **continuous numeric variables**. Its coefficient r ranges from −1 to +1, where values near +1 indicate strong positive correlation, values near −1 indicate strong negative correlation, and values near 0 indicate little or no linear relationship. Pearson correlation assumes approximate normality, linearity, and continuous numeric data. It is useful for exploratory data analysis, feature selection, and checking relationships between variables, but **correlation does not imply causation** and a near-zero Pearson correlation does not rule out non-linear relationships.

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
from pylab import rcParams

import scipy
from scipy.stats import pearsonr

# %%
# %matplotlib inline
rcParams['figure.figsize'] = 8, 4
sns.set_style('whitegrid')

# %% [markdown]
# ### The Pearson correlation

# %%
address = "D:\Tutorials\AI - Engineer\Data_Science_and_ML\data\mtcars.csv"

cars = pd.read_csv(address)
cars.columns = ['car_names','mpg','cyl','disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am', 'gear', 'carb']

# %%
sns.pairplot(cars)

# %%
x = cars[['mpg', 'hp', 'qsec', 'wt']]
sns.pairplot(x)

# %% [markdown]
# ### using scipy to calculate the pearson correlation coefficient

# %%
mpg = cars['mpg']
hp = cars['hp']
qsec = cars['qsec']
wt = cars['wt']

pearsonr_coefficient, p_value = pearsonr(mpg, hp)
print('pearsonr Corelation Coefficient %0.3f' %(pearsonr_coefficient))
# Out:
# pearsonr Corelation Coefficient -0.776

# %%
pearsonr_coefficient, p_value = pearsonr(mpg, qsec)
print('pearsonr Corelation Coefficient %0.3f' %(pearsonr_coefficient))
# Out:
# pearsonr Corelation Coefficient 0.419

# %%
pearsonr_coefficient, p_value = pearsonr(mpg, wt)
print('pearsonr Corelation Coefficient %0.3f' %(pearsonr_coefficient))
# Out:
# pearsonr Corelation Coefficient -0.868

# %% [markdown]
# ### Using Pandas to calcualte the pearson correlation coefficient

# %%
corr = x.corr()
corr
# Out:
#            mpg        hp      qsec        wt
# mpg   1.000000 -0.776168  0.418684 -0.867659
# hp   -0.776168  1.000000 -0.708223  0.658748
# qsec  0.418684 -0.708223  1.000000 -0.174716
# wt   -0.867659  0.658748 -0.174716  1.000000

# %% [markdown]
# ### Using seaborn to visualize the pearson correlation coefficient

# %%
sns.heatmap(corr, xticklabels=corr.columns.values, yticklabels=corr.columns.values)
# Out:
# <Axes: >
