# %% [markdown]
# ## Introduction to the matplotlib and Seaborn libraries

# %%
# !pip install matplotlib
# !pip install seaborn
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.11.1-cp311-cp311-win_amd64.whl.metadata (80 kB)
#      ---------------------------------------- 0.0/80.3 kB ? eta -:--:--
#      ----- ---------------------------------- 10.2/80.3 kB ? eta -:--:--
#      --------- ---------------------------- 20.5/80.3 kB 165.2 kB/s eta 0:00:01
#      -------------- ----------------------- 30.7/80.3 kB 187.9 kB/s eta 0:00:01
#      ------------------- ------------------ 41.0/80.3 kB 219.4 kB/s eta 0:00:01
#      ----------------------------- -------- 61.4/80.3 kB 233.8 kB/s eta 0:00:01
#      ----------------------------- -------- 61.4/80.3 kB 233.8 kB/s eta 0:00:01
#      -------------------------------------- 80.3/80.3 kB 235.8 kB/s eta 0:00:00
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Using cached contourpy-1.3.3-cp311-cp311-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.28.2 (from matplotlib)
#   Downloading fonttools-4.63.0-cp311-cp311-win_amd64.whl.metadata (121 kB)
#      ---------------------------------------- 0.0/121.0 kB ? eta -:--:--
#      --------- ----------------------------- 30.7/121.0 kB 1.3 MB/s eta 0:00:01
#      ----------------------------------- -- 112.6/121.0 kB 1.3 MB/s eta 0:00:01
#      -------------------------------------- 121.0/121.0 kB 1.0 MB/s eta 0:00:00
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Using cached kiwisolver-1.5.0-cp311-cp311-win_amd64.whl.metadata (5.2 kB)
# Requirement already satisfied: numpy>=1.25 in d:\tutorials\ai - engineer\data_science_and_ml\.venv\lib\site-packages (from matplotlib) (2.4.6)
# Requirement already satisfied: packaging>=20.0 in d:\tutorials\ai - engineer\data_science_and_ml\.venv\lib\site-packages (from matplotlib) (26.3)
# Collecting pillow>=9 (from matplotlib)
#   Downloading pillow-12.3.0-cp311-cp311-win_amd64.whl.metadata (9.3 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Using cached pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7 in d:\tutorials\ai - engineer\data_science_and_ml\.venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in d:\tutorials\ai - engineer\data_science_and_ml\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading matplotlib-3.11.1-cp311-cp311-win_amd64.whl (9.3 MB)
#    ---------------------------------------- 0.0/9.3 MB ? eta -:--:--
#    ---------------------------------------- 0.1/9.3 MB 2.2 MB/s eta 0:00:05
#     --------------------------------------- 0.2/9.3 MB 2.3 MB/s eta 0:00:04
#    - -------------------------------------- 0.3/9.3 MB 2.6 MB/s eta 0:00:04
#    - -------------------------------------- 0.5/9.3 MB 2.6 MB/s eta 0:00:04
#    -- ------------------------------------- 0.6/9.3 MB 2.7 MB/s eta 0:00:04
#    --- ------------------------------------ 0.8/9.3 MB 2.9 MB/s eta 0:00:03
#    ---- ----------------------------------- 1.0/9.3 MB 3.0 MB/s eta 0:00:03
#    ---- ----------------------------------- 1.1/9.3 MB 3.1 MB/s eta 0:00:03
#    ----- ---------------------------------- 1.3/9.3 MB 3.1 MB/s eta 0:00:03
#    ------ --------------------------------- 1.4/9.3 MB 3.2 MB/s eta 0:00:03
#    ------ --------------------------------- 1.6/9.3 MB 3.3 MB/s eta 0:00:03
#    -------- ------------------------------- 1.9/9.3 MB 3.4 MB/s eta 0:00:03
#    --------- ------------------------------ 2.2/9.3 MB 3.7 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.5/9.3 MB 3.8 MB/s eta 0:00:02
#    ----------- ---------------------------- 2.7/9.3 MB 4.0 MB/s eta 0:00:02
#    ------------- -------------------------- 3.1/9.3 MB 4.2 MB/s eta 0:00:02
#    -------------- ------------------------- 3.3/9.3 MB 4.2 MB/s eta 0:00:02
#    --------------- ------------------------ 3.6/9.3 MB 4.3 MB/s eta 0:00:02
#    ---------------- ----------------------- 3.9/9.3 MB 4.4 MB/s eta 0:00:02
#    ------------------ --------------------- 4.2/9.3 MB 4.6 MB/s eta 0:00:02
#    ------------------- -------------------- 4.6/9.3 MB 4.7 MB/s eta 0:00:02
#    --------------------- ------------------ 4.9/9.3 MB 4.8 MB/s eta 0:00:01
#    ---------------------- ----------------- 5.2/9.3 MB 4.9 MB/s eta 0:00:01
#    ----------------------- ---------------- 5.6/9.3 MB 5.0 MB/s eta 0:00:01
#    ------------------------- -------------- 6.0/9.3 MB 5.2 MB/s eta 0:00:01
#    -------------------------- ------------- 6.3/9.3 MB 5.2 MB/s eta 0:00:01
#    ---------------------------- ----------- 6.6/9.3 MB 5.3 MB/s eta 0:00:01
#    ------------------------------ --------- 7.1/9.3 MB 5.5 MB/s eta 0:00:01
#    ------------------------------- -------- 7.4/9.3 MB 5.5 MB/s eta 0:00:01
#    --------------------------------- ------ 7.8/9.3 MB 5.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 8.2/9.3 MB 5.7 MB/s eta 0:00:01
#    ------------------------------------ --- 8.4/9.3 MB 5.7 MB/s eta 0:00:01
#    ------------------------------------ --- 8.5/9.3 MB 5.7 MB/s eta 0:00:01
#    ------------------------------------ --- 8.5/9.3 MB 5.7 MB/s eta 0:00:01
#    ------------------------------------ --- 8.5/9.3 MB 5.7 MB/s eta 0:00:01
#    ------------------------------------ --- 8.5/9.3 MB 5.7 MB/s eta 0:00:01
#    ------------------------------------ --- 8.5/9.3 MB 5.7 MB/s eta 0:00:01
#    ------------------------------------ --- 8.5/9.3 MB 5.7 MB/s eta 0:00:01
#    ------------------------------------ --- 8.5/9.3 MB 5.7 MB/s eta 0:00:01
#    ------------------------------------ --- 8.5/9.3 MB 5.7 MB/s eta 0:00:01
#    ------------------------------------ --- 8.6/9.3 MB 4.5 MB/s eta 0:00:01
#    ---------------------------------------  9.3/9.3 MB 4.7 MB/s eta 0:00:01
#    ---------------------------------------  9.3/9.3 MB 4.8 MB/s eta 0:00:01
#    ---------------------------------------- 9.3/9.3 MB 4.7 MB/s eta 0:00:00
# Using cached contourpy-1.3.3-cp311-cp311-win_amd64.whl (225 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.63.0-cp311-cp311-win_amd64.whl (2.4 MB)
#    ---------------------------------------- 0.0/2.4 MB ? eta -:--:--
#    ------ --------------------------------- 0.4/2.4 MB 8.1 MB/s eta 0:00:01
#    ------------- -------------------------- 0.8/2.4 MB 8.4 MB/s eta 0:00:01
#    ------------------ --------------------- 1.1/2.4 MB 8.4 MB/s eta 0:00:01
#    ------------------------- -------------- 1.5/2.4 MB 8.6 MB/s eta 0:00:01
#    ------------------------------- -------- 1.8/2.4 MB 8.3 MB/s eta 0:00:01
#    -------------------------------------- - 2.2/2.4 MB 8.4 MB/s eta 0:00:01
#    ---------------------------------------  2.4/2.4 MB 7.9 MB/s eta 0:00:01
#    ---------------------------------------- 2.4/2.4 MB 7.2 MB/s eta 0:00:00
# Using cached kiwisolver-1.5.0-cp311-cp311-win_amd64.whl (73 kB)
# Downloading pillow-12.3.0-cp311-cp311-win_amd64.whl (7.2 MB)
#    ---------------------------------------- 0.0/7.2 MB ? eta -:--:--
#    - -------------------------------------- 0.4/7.2 MB 11.2 MB/s eta 0:00:01
#    ---- ----------------------------------- 0.8/7.2 MB 9.7 MB/s eta 0:00:01
#    ------ --------------------------------- 1.2/7.2 MB 9.6 MB/s eta 0:00:01
#    -------- ------------------------------- 1.6/7.2 MB 9.2 MB/s eta 0:00:01
#    ----------- ---------------------------- 2.0/7.2 MB 9.1 MB/s eta 0:00:01
#    ------------- -------------------------- 2.4/7.2 MB 9.0 MB/s eta 0:00:01
#    -------------- ------------------------- 2.6/7.2 MB 8.8 MB/s eta 0:00:01
#    ---------------- ----------------------- 3.1/7.2 MB 8.5 MB/s eta 0:00:01
#    ------------------ --------------------- 3.4/7.2 MB 8.7 MB/s eta 0:00:01
#    -------------------- ------------------- 3.7/7.2 MB 8.2 MB/s eta 0:00:01
#    ----------------------- ---------------- 4.2/7.2 MB 8.3 MB/s eta 0:00:01
#    ------------------------- -------------- 4.6/7.2 MB 8.4 MB/s eta 0:00:01
#    --------------------------- ------------ 4.9/7.2 MB 8.3 MB/s eta 0:00:01
#    ----------------------------- ---------- 5.3/7.2 MB 8.3 MB/s eta 0:00:01
#    ------------------------------- -------- 5.8/7.2 MB 8.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 6.2/7.2 MB 8.4 MB/s eta 0:00:01
#    ------------------------------------ --- 6.6/7.2 MB 8.4 MB/s eta 0:00:01
#    -------------------------------------- - 7.0/7.2 MB 8.5 MB/s eta 0:00:01
#    ---------------------------------------  7.2/7.2 MB 8.6 MB/s eta 0:00:01
#    ---------------------------------------- 7.2/7.2 MB 8.1 MB/s eta 0:00:00
# Using cached pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.63.0 kiwisolver-1.5.0 matplotlib-3.11.1 pillow-12.3.0 pyparsing-3.3.2
# [notice] A new release of pip is available: 24.0 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in d:\tutorials\ai - engineer\data_science_and_ml\.venv\lib\site-packages (from seaborn) (2.4.6)
# Requirement already satisfied: pandas>=1.2 in d:\tutorials\ai - engineer\data_science_and_ml\.venv\lib\site-packages (from seaborn) (3.0.5)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in d:\tutorials\ai - engineer\data_science_and_ml\.venv\lib\site-packages (from seaborn) (3.11.1)
# Requirement already satisfied: contourpy>=1.0.1 in d:\tutorials\ai - engineer\data_science_and_ml\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in d:\tutorials\ai - engineer\data_science_and_ml\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.28.2 in d:\tutorials\ai - engineer\data_science_and_ml\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\tutorials\ai - engineer\data_science_and_ml\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in d:\tutorials\ai - engineer\data_science_and_ml\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (26.3)
# Requirement already satisfied: pillow>=9 in d:\tutorials\ai - engineer\data_science_and_ml\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in d:\tutorials\ai - engineer\data_science_and_ml\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in d:\tutorials\ai - engineer\data_science_and_ml\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: tzdata in d:\tutorials\ai - engineer\data_science_and_ml\.venv\lib\site-packages (from pandas>=1.2->seaborn) (2026.3)
# Requirement already satisfied: six>=1.5 in d:\tutorials\ai - engineer\data_science_and_ml\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
#    ---------------------------------------- 0.0/294.9 kB ? eta -:--:--
#    ---------------------------------------- 0.0/294.9 kB ? eta -:--:--
#    ---------------------------------------- 0.0/294.9 kB ? eta -:--:--
#    - -------------------------------------- 10.2/294.9 kB ? eta -:--:--
#    ---- ---------------------------------- 30.7/294.9 kB 217.9 kB/s eta 0:00:02
#    ----- --------------------------------- 41.0/294.9 kB 245.8 kB/s eta 0:00:02
#    ------------ -------------------------- 92.2/294.9 kB 438.1 kB/s eta 0:00:01
#    ------------------------- ------------ 194.6/294.9 kB 787.7 kB/s eta 0:00:01
#    ---------------------------------------- 294.9/294.9 kB 1.1 MB/s eta 0:00:00
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
# [notice] A new release of pip is available: 24.0 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt
import seaborn as sns

from pandas import DataFrame
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
data = {'names':['steve', 'john', 'richard', 'sarah', 'randy', 'micheal', 'julie'],
        'age':[20, 22, 20, 21, 24, 23, 22],
        'gender':['Male', 'Male', 'Male', 'Female', 'Male', 'Male', 'Female'],
        'rank':[2, 1, 4, 5, 3, 7, 6]}

df = DataFrame(data)
df
# Out:
#      names  age  gender  rank
# 0    steve   20    Male     2
# 1     john   22    Male     1
# 2  richard   20    Male     4
# 3    sarah   21  Female     5
# 4    randy   24    Male     3
# 5  micheal   23    Male     7
# 6    julie   22  Female     6

# %% [markdown]
# ## Matplotlib Bar Chart

# %%
plt.bar(df["names"], df["age"])
plt.xlabel("Names")
plt.ylabel("Age")
plt.title("Comparing Ages")
plt.show()

# %% [markdown]
# ## Seaborn Bar Chart

# %%
plot = sns.barplot(data=df, x="names", y="age")
plot.set_title("comparing with ages")
plt.show()

# %% [markdown]
# ## Line Plot Matplotlib

# %%
plt.plot(df["names"], df["age"])
plt.xlabel("Names")
plt.ylabel("Ages")
plt.title("Comparing Ages")
plt.show()

# %% [markdown]
# ## Line Plot for Seaborn

# %%
plot = sns.lineplot(data=df, x="names", y="age")
plot.set_title("Commparing age")
plt.show()

# %% [markdown]
# ## Pie in Matplotlib

# %%
plt.pie(df["age"], labels=df["names"])
plt.title("Comapring ages")
plt.show()

# %% [markdown]
# ## Pie in Seaborn

# %%
colors = sns.color_palette('pastel')[0:5]
plt.pie(df['age'], labels=df['names'], colors=colors)
plt.show()
