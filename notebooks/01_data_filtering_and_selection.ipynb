# %% [markdown]
# # Data Filtering and Selection

# %%
# !pip install --upgrade pip
# !pip install numpy
# !pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#     --------------------------------------- 0.0/1.8 MB 435.7 kB/s eta 0:00:05
#    -- ------------------------------------- 0.1/1.8 MB 744.7 kB/s eta 0:00:03
#    ----- ---------------------------------- 0.3/1.8 MB 1.6 MB/s eta 0:00:01
#    ----------- ---------------------------- 0.5/1.8 MB 2.7 MB/s eta 0:00:01
#    ----------------- ---------------------- 0.8/1.8 MB 3.3 MB/s eta 0:00:01
#    ----------------------- ---------------- 1.1/1.8 MB 3.6 MB/s eta 0:00:01
#    ------------------------------- -------- 1.4/1.8 MB 4.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 1.6/1.8 MB 4.1 MB/s eta 0:00:01
#    ---------------------------------------  1.8/1.8 MB 4.3 MB/s eta 0:00:01
#    ---------------------------------------- 1.8/1.8 MB 4.0 MB/s eta 0:00:00
# ERROR: To modify pip, please run the following command:
# ...

# %%
import numpy as np
import pandas as pd

from pandas import DataFrame

# %%
number_df = DataFrame(np.arange(0,90,3).reshape(10,3), index= ['row 1','row 2','row 3','row 4','row 5','row 6','row 7','row 8','row 9','row 10'],columns=['column 1','column 2','column 3'])
number_df
# Out:
#         column 1  column 2  column 3
# row 1          0         3         6
# row 2          9        12        15
# row 3         18        21        24
# row 4         27        30        33
# row 5         36        39        42
# row 6         45        48        51
# row 7         54        57        60
# row 8         63        66        69
# row 9         72        75        78
# row 10        81        84        87

# %%
number_df.iloc[0, 1]
# Out:
# np.int64(3)

# %%
number_df.iloc[0,1]=20
number_df
# Out:
#         column 1  column 2  column 3
# row 1          0        20         6
# row 2          9        12        15
# row 3         18        21        24
# row 4         27        30        33
# row 5         36        39        42
# row 6         45        48        51
# row 7         54        57        60
# row 8         63        66        69
# row 9         72        75        78
# row 10        81        84        87
